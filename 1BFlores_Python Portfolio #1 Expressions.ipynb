# %% [markdown]
# # Portfolio #1 Expressions #

# %% [markdown]
# Direction: Create a personalized code tackling the concepts defined in *Chapter 2: Variables, Expressions, and Statements*

# %% [markdown]
# _________________________________________________________

# %% [markdown]
# **1. Variables**

# %%
name = "FLORES, Nicole Zeyh C."
course = "BSChE-1B"
status = "PASSED"
print(f"Full name: {name} Course: {course}")

print(f"Status: {status}")
# Out:
# Full name: FLORES, Nicole Zeyh C. Course: BSChE-1B
# Status: PASSED

# %% [markdown]
# _________________________________________________________

# %% [markdown]
# **2. Expressions**

# %%
mes = "Grades"
g1 = 1.0
g2 = 1.8
g3 = 2.5
g4 = 1.75
g5 = 1.5

ave = (g1+g2+g3+g4+g5)/5

print (mes)
print (f" PathFit 2: {g1}")
print (f" Math12: {g2}")
print (f" Chem12L: {g3}")
print (f" Chem12: {g4}")
print (f" Phys11: {g5}")

print (f" Average: {ave}")
# Out:
# Grades
#  PathFit 2: 1.0
#  Math12: 1.8
#  Chem12L: 2.5
#  Chem12: 1.75
#  Phys11: 1.5
#  Average: 1.7100000000000002

# %% [markdown]
# *note: Python evaluates expressions from left to right*

# %% [markdown]
# _________________________________________________________
